# %%
# question 1-explain the key feature of python that make it a popular choice for programming

# there are so many properties that python have which make it a popular among other languages some Key features of Python are listed below:

# Readability: Python emphasizes code readability with its clear syntax as it has simple english keywords.
# User friendly: python codes are easily understandable to others and has more fexilbly for diff users like data scienece ,ML , data analysts
# image processing feature
# In build library: Python have so many inbuild libray
# Large Community: Python has widely used in industry


# Question 2-Describle the role of predefined keywords in python and provide example of how they are used in a programing

# Predefined keywords in Python are reserved words that hold a special meaning and have special purpose in python language
# These keywords play crucial roles in defining the structure and logic of Python code.
# Examples of keywords include: if, else, for, while, def, class, import, and many more.
# use of keywords "if" and "else" are used for conditional statements, "for" and "while" for loops.
a==10
if a==10:
    print("a is equal to 10")
else:
    print("a is not equal to 10")


# Question 3-compare and contrast mutable and immutable objects in python with example

# Mutable objects can be changed after creation
# Immutable objects cannot be changed after creation

# Mutable objects:
# a = [1, 2, 3]
# a[2]=4  # Modifies the original list
# print(a)  # Output: [1, 2, 4]
# list are mutubale

# Immutable objects:
# b = "hello world "
# b[0] = "H"  # This would cause an error because pyhon is a  case sensitive language



#Question 4 discuss different types of operators in python and provide example of how they are used

# Arithmetic Operators:
# Used for basic mathematical operations.
x = 10
y = 5

#  Addition:print  (x + y) - 15
# Subtraction:print  (x - y)  - 5
# Multiplication:  print(x * y) -50
# Division:   print(x / y)  -2.0
# Modulus:   print(x % y)  - 0
# Exponentiation:    print(x ** y)  -100000


# Comparison Operators:
# Used to compare values and return True or False.
a = 5
b = 10

# Equal to:print(a == b)   -False
# Not equal to: print(a != b)   -True
 # Less than:  print(a < b)   -True
# Greater than:  print(a > b)    -False
# Less than or equal to:  print(a <= b)   -True
# Greater than or equal to:   print(a >= b)   -False


# Logical Operators:
# Used to combine conditional statements.
p = True
q = False

# Logical AND:   print(p and q)   -False
# Logical OR:   print(p or q)    -True
# Logical NOT:  print(not p)     -False


# Assignment Operators:
# Used to assign values to variables.
num = 10
# Add and assign:   num += 5      - num = num + 5
# print(num)  Output: 15

# Other assignment operators include: -=, *=, /=, %=, **=

# Membership Operators:
# Used to test if a value is a member of a sequence.
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)  # True
print("orange" not in fruits)  # True


# Identity Operators:
# Used to compare the memory locations of two objects.
x = [1, 2, 3]
y = x
z = [1, 2, 3]

print(x is y)   # True (x and y refer to the same object)
print(x is z)   # False (x and z are different objects)
print(x is not y)  # False
print(x is not z)  # True



# Question 5- Explain the concept of type casting in python with

# Type casting in Python refers to the process of converting one data type to another.
# Here are some common type casting functions in Python:

# int(): Converts a value to an integer.
x = int(3.14)  # x will be 3

# float(): Converts a value to a floating-point number.
y = float(5)  # y will be 5.0

# Type casting can be explicit (using functions like int(), float(), etc.) or implicit (done automatically by Python in some cases).
# It's important to note that not all type conversions are possible. For example, you cannot convert a string like "hello" to an integer.


# question 6- how do conditional statement work in python? illustrate with example

# Conditional statements in Python is used to execute a conditional based prgram
# The most common conditional statement is the "if" "elif " and "else"
grade = 85
if grade >= 90:
  print("A")
elif grade >= 80:
  print("B")
elif grade >= 70:
  print("C")
else:
  print("D")


# Question 7- Describe the  different types of loops in python and their cases with example

# There are two primary types of loops in Python:

# 1. For Loop:
# Used to iterate over a sequence (e.g., list, tuple, string, range).

fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
  print(fruit)

# 2. While Loop:
# Used to repeatedly execute a block of code as long as a condition is true.

count = 0
while count < 5:
  print(count)
  count += 1
